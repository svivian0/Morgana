# %%
import pandas as pd

df=pd.read_csv("teste.csv")
df
# Out:
#     X   Y
# 0  24  60
# 1  26  65
# 2  28  70
# 3  30  75
# 4  32  80

# %%
df.plot(kind="scatter", x="X",y="Y");

# %%
from sklearn import linear_model

modelo=linear_model.LinearRegression()
x=df[["X"]]
y=df[["Y"]]
modelo.fit( x, y)
# Out:
# LinearRegression()

# %%
print(modelo.predict([[2]])[0][0])
# Out:
# 5.000000000000013
# c:\Users\gui_b\Morgana\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
